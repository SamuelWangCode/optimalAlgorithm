# %%
from DE import *
from ABC import *
from CS import *
from CSA import *
from PSO import *
from SA import *
import numpy as np
from matplotlib import pyplot as plt
from test_function import *

# %%
fun = np.zeros((10, 30, 6, 50))
for i in range(10):
    for j in range(30):
        sa = SA(i, j+1)
        pso = PSO(i, j+1)
        de = DE(i, j+1)
        abc = ABC(i, j+1)
        csa = CSA(i, j+1)
        cs = CS(i, j+1)
        for p in range 50:
            sa.get_SA()
            fun[i][j][0][p] = sa.global_opt
            pso.get_PSO()
            fun[i][j][1][p] = pso.global_opt
            de.get_DE()
            fun[i][j][2][p] = de.global_opt
            abc.get_ABC()
            fun[i][j][3][p] = abc.global_opt
            csa.get_CSA()
            fun[i][j][4][p] = csa.global_opt
            cs.get_CS()
            fun[i][j][5][p] = cs.global_opt
# Out:
# 满足终止条件，迭代结束
# 粒子的最优位置为：
# [-0.04231406]
# 粒子的最优函数值为：
# 0.26239045025595376
# 一共计算了2501次函数值
# 满足终止条件，迭代结束
# 粒子的最优位置为：
# [-3.55112939e-10]
# 粒子的最优函数值为：
# 1.4204535325745837e-09
# 一共计算了2550次函数值
# 满足终止条件，迭代结束
# 粒子的最优位置为：
# [-1.89828654e-11]
# 粒子的最优函数值为：
# 7.592904083253416e-11
# 一共计算了2550次函数值
# 满足终止条件，迭代结束
# 粒子的最优位置为：
# [-2.21517531e-14]
# 粒子的最优函数值为：
# 8.926193117986259e-14
# 一共计算了2525次函数值
# 满足终止条件，迭代结束
# 粒子的最优位置为：
# [-0.00287806]
# 粒子的最优函数值为：
# 0.011953315728821412
# 一共计算了2470次函数值
# 满足终止条件，迭代结束
# 粒子的最优位置为：
# [1.75140081e-11]
# 粒子的最优函数值为：
# 7.005640512147693e-11
# 一共计算了2525次函数值
# 满足终止条件，迭代结束
# 粒子的最优位置为：
# [-0.06005956 -0.45357863]
# 粒子的最优函数值为：
# 2.985378436421201
# 一共计算了2501次函数值
# 满足终止条件，迭代结束
# 粒子的最优位置为：
# [ 3.77288037e-09 -1.42044500e-07]
# 粒子的最优函数值为：
# 4.019047499248529e-07
# 一共计算了2550次函数值
# 满足终止条件，迭代结束
# 粒子的最优位置为：
# [-2.16988228e-06 -6.42357983e-06]
# 粒子的最优函数值为：
# 1.917845374466154e-05
# 一共计算了2550次函数值
# 满足终止条件，迭代结束
# 粒子的最优位置为：
# [-2.56468401e-06  5.55718930e-07]
# 粒子的最优函数值为：
# ...
